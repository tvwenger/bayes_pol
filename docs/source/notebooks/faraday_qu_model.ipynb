# %% [markdown]
# # `FaradayQUModel` Tutorial
#
# Trey V. Wenger (c) March 2025
#
# Here we demonstrate the basic features of the `FaradayQUModel` model. The `FaradayQUModel` predicts Stokes Q, U, and Faraday depth spectra by decomposing the line-of-sight into a series of Faraday-thin (delta function) or Faraday-thick (Gaussian) components. Please review the `bayes_spec` documentation and tutorials for a more thorough description of the steps outlined in this tutorial: https://bayes-spec.readthedocs.io/en/stable/index.html

# %%
# General imports    
import os
import pickle
import time

import matplotlib.pyplot as plt
import arviz as az
import pandas as pd
import numpy as np
import pymc as pm

print("pymc version:", pm.__version__)

import bayes_spec
print("bayes_spec version:", bayes_spec.__version__)

import bayes_pol
print("bayes_pol version:", bayes_pol.__version__)

# Notebook configuration
pd.options.display.max_rows = None
# Out:
# pymc version: 5.21.1
# bayes_spec version: 1.7.5
# bayes_pol version: 1.0+14.g39245d2.dirty

# %% [markdown]
# ## Simulating Data
#
# To test the model, we must simulate some data. We can do this with `FaradayModel`, but we must pack a "dummy" data structure first. Here we construct a dataset that is similar to a "real" dataset: multiple non-contiguous frequency windows, uniform sampling in frequency, and different noise properties in each window.

# %%
from bayes_spec import SpecData

# speed of light (m Hz)
_C = 2.99792458e+08

# frequency windows (start_edge (Hz), stop_edge (Hz), n_channels, spectral rms (%))
freq_windows = [
#    (0.5e9, 0.8e9, 128, 0.5),
    (1.1e9, 1.4e9, 128, 0.01),
#    (2.0e9, 2.1e9, 64, 0.1),
]

# storage for dummy data, concatenated Stokes data, and wavelength bin data
dummy_data = {}
all_lam2_axis = []
all_stokesQ = []
all_stokesU = []
lam2_lower = []
lam2_upper = []
lam2_chans = []
lam2_channel_widths = []

# loop over windows
for i, window in enumerate(freq_windows):
    # construct frequency bins
    freq_bin_edges = np.linspace(window[0], window[1], window[2]+1)
    freq_bin_width = np.diff(freq_bin_edges)[0]

    # frequency bin centers
    freq_axis = freq_bin_edges[:-1] + freq_bin_width/2.0

    # convert to wavelength bins
    lam2_bin_edges = (_C/freq_bin_edges[::-1])**2.0
    lam2_bin_widths = np.diff(lam2_bin_edges)

    # (weighted) wavelength^2 bin centers
    lam2_axis = lam2_bin_edges[:-1] + _C**2.0/freq_axis[::-1]**3.0 * freq_bin_width
    
    # random Stokes data for now
    stokesQ = window[3] * np.random.randn(len(lam2_axis))
    stokesU = window[3] * np.random.randn(len(lam2_axis))

    dummy_data[f"Q{i}"] = SpecData(
        lam2_axis, # spectral
        stokesQ, # brightness
        window[3], # rms
        xlabel = r"$\lambda^2$ (m$^2$)",
        ylabel = r"$Q/I$",
    )
    dummy_data[f"U{i}"] = SpecData(
        lam2_axis, # spectral
        stokesU, # brightness
        window[3], # rms
        xlabel = r"$\lambda^2$ (m$^2$)",
        ylabel = r"$U/I$",
    )
    
    # save data
    all_lam2_axis.append(lam2_axis)
    all_stokesQ.append(stokesQ)
    all_stokesU.append(stokesU)
    lam2_lower.append(lam2_bin_edges.min())
    lam2_upper.append(lam2_bin_edges.max())
    lam2_chans.append(len(lam2_axis))
    lam2_channel_widths.append(lam2_bin_widths)

# concatenate along window axis
lam2_axis = np.concatenate(all_lam2_axis)
stokesQ = np.concatenate(all_stokesQ)
stokesU = np.concatenate(all_stokesU)

# %% [markdown]
# Now we construct the Faraday spectrum from the (random, for now) Stokes Q and U data.

# %%
from bayes_pol.utils import construct_faraday_spectrum, construct_rmsf
from bayes_spec import SpecData

# Tunable parameters
faraday_width = 1000.0 # rad/m2
resolution_factor = 25 # Faraday bins per resolution element

# Faraday depth spectral axis
max_scale = np.pi/np.abs(np.diff(lam2_axis)).min()
resolution = np.pi/np.ptp(lam2_axis)

N_bins = int(resolution_factor * faraday_width / resolution)
if N_bins % 2 == 0:
    N_bins += 1
faraday_depth_axis = np.linspace(-faraday_width/2.0, faraday_width/2.0, N_bins)
print(f"Faraday depth max scale: {max_scale:0.1f} rad/m2")
print(f"Faraday depth resolution: {resolution:0.1f} rad/m2")
print(f"Faraday bins: {N_bins:d}")
print(f"Faraday bin width: {np.diff(faraday_depth_axis)[0]:0.1f} rad/m2")
print(f"Independent Faraday bins: {int(faraday_width/resolution):d}")
print(f"Wavelength bins: {len(lam2_axis):d}")

# construct FDF from Stokes Q and U
faraday_depth_real, faraday_depth_imag = construct_faraday_spectrum(faraday_depth_axis, lam2_axis, stokesQ, stokesU)
faraday_depth_abs = np.sqrt(faraday_depth_real.eval()**2.0 + faraday_depth_imag.eval()**2.0)
faraday_depth_rms = np.sqrt(np.sum([window[2]*window[3]**2.0 for window in freq_windows])/len(lam2_axis)**2.0)
dummy_data["faraday_depth_abs"] = SpecData(
    faraday_depth_axis, # spectral axis
    faraday_depth_abs, # brightness data
    faraday_depth_rms,
    xlabel=r"$\phi$ (rad m$^{-2}$)",
    ylabel=r"$|F(\phi)|$",
)

# construct RMSF
rmsf_real, rmsf_imag = construct_faraday_spectrum(faraday_depth_axis, lam2_axis, np.ones_like(stokesQ), np.zeros_like(stokesU))
rmsf_abs = np.sqrt(rmsf_real.eval()**2.0 + rmsf_imag.eval()**2.0)

# Plot the simulated data
fig, axes = plt.subplots(len(dummy_data)+1, figsize=(8, 4*(len(dummy_data)+1)), layout="constrained", squeeze=False)
for ax, dataset in zip(axes.ravel(), dummy_data.values()):
    ax.plot(dataset.spectral, dataset.brightness, "k-")
    ax.set_xlabel(dataset.xlabel)
    ax.set_ylabel(dataset.ylabel)
    ax.legend(loc='best')
ax.axhline(faraday_depth_rms, color='b', label='rms')

ax = axes.ravel()[-1]
ax.plot(faraday_depth_axis, rmsf_abs, 'k-')
ax.set_xlabel(dataset.xlabel)
ax.set_ylabel("RMSF")
ax.set_yscale("log")
# Out:
# Faraday depth max scale: 20359.4 rad/m2
# Faraday depth resolution: 111.5 rad/m2
# Faraday bins: 225
# Faraday bin width: 4.5 rad/m2
# Independent Faraday bins: 8
# Wavelength bins: 128
# /tmp/ipykernel_381989/1760292319.py:45: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='best')

# %% [markdown]
# Now that we have a dummy data format, we can generate a simulated observation by evaluating the model for a given set of parameters. We mimic a "real" dataset by constructing the Faraday spectrum from Stokes Q and U (rather than simulating it from the model). We compare it to the model prediction as a test of the model.

# %%
from bayes_pol import FaradayQUModel

# Initialize and define the model
n_clouds = 2 # number of cloud components
model = FaradayQUModel(
    dummy_data,
    lam2_lower=lam2_lower,
    lam2_upper=lam2_upper,
    lam2_chans=lam2_chans,
    n_clouds=n_clouds,
    seed=1234,
    verbose=True
)
model.add_priors(
    prior_faraday_depth_mean = [0.0, 250.0],
    prior_faraday_depth_fwhm = 25.0,
)
model.add_likelihood()

# simulation parameters
sim_params = {
    "polarization_fraction": np.array([0.8, 0.4]),
    "faraday_depth_mean": np.array([-50.0, 250.0]),
    "faraday_depth_fwhm": np.array([0.0, 30.0]),
    "pol_angle0": np.array([-0.25, 0.45]),
    "mixture_weight": np.array([1.0, 0.0]),  # fully Ricean
}

# simulate observations
sim_obs = {
    key: model.model[key].eval(sim_params, on_unused_input="ignore")
    for key in dummy_data.keys() if key != "faraday_depth_abs"
}

# construct Faraday spectrum from Stokes Q and U.
stokesQ = np.concatenate([sim_obs[key] for key in sim_obs.keys() if "Q" in key])
stokesU = np.concatenate([sim_obs[key] for key in sim_obs.keys() if "U" in key])
faraday_depth_real, faraday_depth_imag = construct_faraday_spectrum(faraday_depth_axis, lam2_axis, stokesQ, stokesU)
faraday_depth_abs = np.sqrt(faraday_depth_real.eval()**2.0 + faraday_depth_imag.eval()**2.0)

# save data
data = {}
for key in dummy_data.keys():
    data[key] = SpecData(
        dummy_data[key].spectral,
        sim_obs[key] if "Q" in key or "U" in key else faraday_depth_abs,
        dummy_data[key].noise,
        xlabel=dummy_data[key].xlabel,
        ylabel=dummy_data[key].ylabel,
    )

# Plot the simulated data
fig, axes = plt.subplots(len(data), figsize=(8, 12), layout="constrained", squeeze=False)
for ax, dataset in zip(axes.ravel(), data.values()):
    ax.plot(dataset.spectral, dataset.brightness, "k.")
    ax.set_xlabel(dataset.xlabel)
    ax.set_ylabel(dataset.ylabel)
#ax.plot(dataset.spectral, sim_obs["faraday_depth_abs"], "r-", label="Model")
#ax.legend(loc="upper right")
#ax.set_xlim(-5000, 5000)

# %% [markdown]
# ## Model Definition
#
# Finally, with our model definition and (simulated) data in hand, we can explore the capabilities of `FaradayModel`. Here we create a new model with the simulated data.

# %%
# Initialize and define the model
model = FaradayQUModel(
    data,
    lam2_lower=lam2_lower,
    lam2_upper=lam2_upper,
    lam2_chans=lam2_chans,
    n_clouds=n_clouds,
    seed=1234,
    verbose=True
)
model.add_priors(
    prior_faraday_depth_mean = [0.0, 200.0],
    prior_faraday_depth_fwhm = 50.0,
)
model.add_likelihood()

# %%
# Plot model graph
model.graph().render('faraday_qu_model', format='png')
model.graph()

# %%
# model string representation
print(model.model.str_repr())
# Out:
#   polarization_fraction ~ Beta(2, 2)
# faraday_depth_mean_norm ~ Normal(0, 1)
# faraday_depth_fwhm_norm ~ HalfNormal(0, 1)
#         pol_angle0_norm ~ Uniform(-3.14, 3.14)
#          mixture_weight ~ Dirichlet(<constant>)
#      faraday_depth_mean ~ Deterministic(f(faraday_depth_mean_norm))
#      faraday_depth_fwhm ~ Deterministic(f(faraday_depth_fwhm_norm))
#              pol_angle0 ~ Deterministic(f(pol_angle0_norm))
#                      Q0 ~ Normal(f(polarization_fraction, pol_angle0_norm, faraday_depth_mean_norm, faraday_depth_fwhm_norm), <constant>)
#                      U0 ~ Normal(f(polarization_fraction, pol_angle0_norm, faraday_depth_mean_norm, faraday_depth_fwhm_norm), <constant>)
#       faraday_depth_abs ~ MarginalMixture(mixture_weight, Rice(f(polarization_fraction, faraday_depth_fwhm_norm, pol_angle0_norm, faraday_depth_mean_norm), <constant>), TruncatedNormal(f(polarization_fraction, faraday_depth_fwhm_norm, pol_angle0_norm, faraday_depth_mean_norm), <constant>, 0, inf))

# %% [markdown]
# We check that our prior distributions are reasonable by drawing prior predictive checks. Each colored line is a simulated "observation" with parameters drawn from the prior distributions. You should check that these simulated observations at least somewhat overlap your actual observation (black line).

# %%
from bayes_spec.plots import plot_predictive

# prior predictive check
prior = model.sample_prior_predictive(
    samples=100,  # prior predictive samples
)
axes = plot_predictive(model.data, prior.prior_predictive)
axes.ravel()[0].figure.set_size_inches(8, 16)
# Out:
# Sampling: [Q0, U0, faraday_depth_abs, faraday_depth_fwhm_norm, faraday_depth_mean_norm, mixture_weight, pol_angle0_norm, polarization_fraction]

# %% [markdown]
# Finally, we check the prior distributions of the derived (deterministic) quantities. The red points show the "true" values for our simulated observation.

# %%
from bayes_spec.plots import plot_pair

_ = plot_pair(
    prior.prior, # samples
    model.cloud_deterministics + ["polarization_fraction"],
    labeller=model.labeller, # label manager
    kind="kde", # plot type
    reference_values=sim_params, # truths
)

# %% [markdown]
# ## Variational Inference
#
# We can approximate the posterior distribution using variational inference.

# %%
start = time.time()
model.fit(
    n = 100_000, # maximum number of VI iterations
    draws = 1_000, # number of posterior samples
    rel_tolerance = 0.001, # VI relative convergence threshold
    abs_tolerance = 0.001, # VI absolute convergence threshold
    learning_rate = 0.01, # VI learning rate
)
end = time.time()
print(f"Runtime: {(end-start)/60.0:.2f} minutes")
# Out:
# /home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pytensor/gradient.py:1479: UserWarning: SquareFreqRMSF.grad returned DisconnectedType for input 1. You may want to implement a connection_pattern method for it.
#   warnings.warn(msg)
# /home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pytensor/gradient.py:1479: UserWarning: SquareFreqRMSF.grad returned DisconnectedType for input 2. You may want to implement a connection_pattern method for it.
#   warnings.warn(msg)
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Interrupted at 21,944 [21%]: Average Loss = 5.2363e+06
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 start = time.time()
# ----> 2 model.fit(
#       3     n = 100_000, # maximum number of VI iterations
#       4     draws = 1_000, # number of posterior samples
#       5     rel_tolerance = 0.001, # VI relative convergence threshold
#       6     abs_tolerance = 0.001, # VI absolute convergence threshold
#       7     learning_rate = 0.01, # VI learning rate
#       8 )
#       9 end = time.time()
#      10 print(f"Runtime: {(end-start)/60.0:.2f} minutes")
#
# File ~/science/python/bayes_spec/bayes_spec/base_model.py:491, in BaseModel.fit(self, n, draws, rel_tolerance, abs_tolerance, learning_rate, **kwargs)
#     488     self.trace = self.approx.sample(draws)
#     490 with self.model:
# --> 491     pm.compute_log_likelihood(self.trace)
#
# File ~/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/stats/log_density.py:63, in compute_log_likelihood(idata, var_names, extend_inferencedata, model, sample_dims, progressbar, compile_kwargs)
#      31 def compute_log_likelihood(
#      32     idata: InferenceData,
#      33     *,
#    (...)     39     compile_kwargs: dict[str, Any] | None = None,
#      40 ):
#      41     """Compute elemwise log_likelihood of model given InferenceData with posterior group.
#      42
#      43     Parameters
#    (...)     61         InferenceData with log_likelihood group
#      62     """
# ---> 63     return compute_log_density(
#      64         idata=idata,
#      65         var_names=var_names,
#      66         extend_inferencedata=extend_inferencedata,
#      67         model=model,
#      68         kind="likelihood",
#      69         sample_dims=sample_dims,
#      70         progressbar=progressbar,
#      71         compile_kwargs=compile_kwargs,
#      72     )
#
# File ~/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/stats/log_density.py:167, in compute_log_density(idata, var_names, extend_inferencedata, model, kind, sample_dims, progressbar, compile_kwargs)
#     164     raise ValueError("kind must be either 'likelihood' or 'prior'")
#     166 # We need to disable transforms, because the InferenceData only keeps the untransformed values
# --> 167 umodel = remove_value_transforms(model)
#     169 if kind == "likelihood":
#     170     target_rvs = list(umodel.observed_RVs)
#
# File ~/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/model/transform/conditioning.py:362, in remove_value_transforms(model, vars)
#     360 if vars is None:
#     361     vars = model.free_RVs
# --> 362 return change_value_transforms(model, {var: None for var in vars})
#
# File ~/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/model/transform/conditioning.py:286, in change_value_transforms(model, vars_to_transforms)
#     283 if set(vars_to_transforms.keys()) - set(model.free_RVs):
#     284     raise ValueError(f"All keys must be free variables in the model: {model.free_RVs}")
# --> 286 fgraph, memo = fgraph_from_model(model)
#     288 vars_to_transforms = {memo[var]: transform for var, transform in vars_to_transforms.items()}
#     289 replacements = {}
#
# File ~/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/model/fgraph.py:153, in fgraph_from_model(model, inlined_views)
#     132 """Convert Model to FunctionGraph.
#     133
#     134 See: model_from_fgraph
#    (...)    150     A dictionary mapping original model variables to the equivalent nodes in the fgraph.
#     151 """
#     152 if any(v is not None for v in model.rvs_to_initial_values.values()):
# --> 153     raise NotImplementedError("Cannot convert models with non-default initial_values")
#     155 if model.parent is not None:
#     156     raise ValueError(
#     157         "Nested sub-models cannot be converted to fgraph. Convert the parent model instead"
#     158     )
#
# NotImplementedError: Cannot convert models with non-default initial_values

# %%
# ignore transition and state dependent parameters
pm.summary(model.trace.posterior)
# Out:
# arviz - WARNING - Shape validation failed: input_shape: (1, 1000), minimum_shape: (chains=2, draws=4)
#                                 mean      sd    hdi_3%   hdi_97%  mcse_mean  \
# polarization_fraction[0]       0.999   0.002     0.997     1.000      0.000
# polarization_fraction[1]       0.998   0.000     0.998     0.998      0.000
# faraday_depth_mean_norm[0]    -3.180   0.000    -3.180    -3.179      0.000
# faraday_depth_mean_norm[1]    -0.241   0.000    -0.242    -0.241      0.000
# faraday_depth_fwhm_norm[0]    29.901   0.534    29.014    31.007      0.016
# faraday_depth_fwhm_norm[1]     0.259   0.000     0.259     0.260      0.000
# pol_angle0_norm[0]             2.574   0.024     2.529     2.616      0.001
# pol_angle0_norm[1]            -0.766   0.008    -0.779    -0.751      0.000
# mixture_weight[0]              0.023   0.037     0.000     0.076      0.001
# mixture_weight[1]              0.977   0.037     0.924     1.000      0.001
# faraday_depth_mean[0]       -635.949   0.054  -636.057  -635.853      0.002
# faraday_depth_mean[1]        -48.243   0.072   -48.378   -48.110      0.002
# faraday_depth_fwhm[0]       1495.044  26.687  1450.694  1550.349      0.811
# faraday_depth_fwhm[1]         12.960   0.009    12.945    12.977      0.000
# pol_angle0[0]                  1.287   0.012     1.265     1.308      0.000
# pol_angle0[1]                 -0.383   0.004    -0.390    -0.375      0.000
#
#                             mcse_sd  ess_bulk  ess_tail  r_hat
# polarization_fraction[0]      0.000    1027.0     962.0    NaN
# polarization_fraction[1]      0.000    1043.0     983.0    NaN
# faraday_depth_mean_norm[0]    0.000     833.0     972.0    NaN
# faraday_depth_mean_norm[1]    0.000     891.0     880.0    NaN
# faraday_depth_fwhm_norm[0]    0.012    1078.0     972.0    NaN
# faraday_depth_fwhm_norm[1]    0.000     942.0     525.0    NaN
# pol_angle0_norm[0]            0.001     963.0     961.0    NaN
# pol_angle0_norm[1]            0.000     948.0     975.0    NaN
# mixture_weight[0]             0.003     973.0     908.0    NaN
# mixture_weight[1]             0.003     973.0     908.0    NaN
# faraday_depth_mean[0]         0.001     833.0     972.0    NaN
# faraday_depth_mean[1]         0.002     891.0     880.0    NaN
# faraday_depth_fwhm[0]         0.612    1078.0     972.0    NaN
# faraday_depth_fwhm[1]         0.000     942.0     525.0    NaN
# pol_angle0[0]                 0.000     963.0     961.0    NaN
# pol_angle0[1]                 0.000     948.0     975.0    NaN

# %%
posterior = model.sample_posterior_predictive(
    thin=100, # keep one in {thin} posterior samples
)
axes = plot_predictive(model.data, posterior.posterior_predictive)
axes.ravel()[0].figure.set_size_inches(8, 16)
# Out:
# Sampling: [Q0, U0, faraday_depth_abs]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## Posterior Sampling: MCMC
#
# We can sample from the posterior distribution using MCMC.

# %%
model.sample_smc(chains=4, cores=4)
# Out:
# Initializing SMC sampler...
# Sampling 4 chains in 4 jobs
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/formatters.py", line 282, in catch_format_error
#     r = method(self, *args, **kwargs)
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/formatters.py", line 972, in __call__
#     if self.enabled:
#        ^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/traitlets/traitlets.py", line 687, in __get__
#     return t.cast(G, self.get(obj, cls))  # the G should encode the Optional
#                      ~~~~~~~~^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/traitlets/traitlets.py", line 666, in get
#     return t.cast(G, value)
#            ~~~~~~^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 2173, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#         etype, value, tb, tb_offset=tb_offset
#     )
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/ultratb.py", line 1182, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self, etype, evalue, etb, tb_offset, context
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/ultratb.py", line 1053, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self, etype, evalue, etb, tb_offset, context
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/concurrent/futures/process.py", line 254, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/smc/sampling.py", line 328, in _sample_smc_int
#     smc.mutate()
#     ~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/smc/kernels.py", line 433, in mutate
#     pearson_r = corr.get(self.tempered_posterior)
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/smc/kernels.py", line 471, in get
#     return np.abs(ab / (self.aa * bb))
#                   ~~~^~~~~~~~~~~~~~~~
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/warnings.py", line 113, in _showwarnmsg
#     _showwarnmsg_impl(msg)
#     ~~~~~~~~~~~~~~~~~^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/warnings.py", line 30, in _showwarnmsg_impl
#     file.write(text)
#     ~~~~~~~~~~^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 43, in write
#     with console:
#          ^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
# ...
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 285, in display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 73, in publish_display_data
#     display_pub.publish(
#     ~~~~~~~~~~~~~~~~~~~^
#         data=data,
#         ^^^^^^^^^^
#         metadata=metadata,
#         ^^^^^^^^^^^^^^^^^^
#         **kwargs
#         ^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 103, in publish
#     self._flush_streams()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/ipykernel/zmqshell.py", line 66, in _flush_streams
#     sys.stdout.flush()
#     ~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 53, in flush
#     self.__console.print(output)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 1692, in print
#     with self:
#          ^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 866, in __exit__
#     self._exit_buffer()
#     ~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 824, in _exit_buffer
#     self._check_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2033, in _check_buffer
#     self._write_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 2049, in _write_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#     ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/display_functions.py", line 278, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#                            ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/formatters.py", line 204, in format
#     if self.ipython_display_formatter(obj):
#        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/decorator.py", line 235, in fun
#     return caller(func, *(extras + args), **kw)
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/formatters.py", line 290, in catch_format_error
#     ip.showtraceback(exc_info)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/IPython/core/interactiveshell.py", line 2178, in showtraceback
#     print(
#     ~~~~~^
#         "Unexpected exception formatting exception. Falling back to standard exception"
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/file_proxy.py", line 43, in write
#     with console:
#          ^^^^^^^
#   File "/home/twenger/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/rich/console.py", line 861, in __enter__
#     self._enter_buffer()
#     ~~~~~~~~~~~~~~~~~~^^
# RecursionError: maximum recursion depth exceeded
# """
#
# The above exception was the direct cause of the following exception:
#
# RecursionError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.sample_smc(chains=4, cores=4)
#
# File ~/science/python/bayes_spec/bayes_spec/base_model.py:607, in BaseModel.sample_smc(self, **kwargs)
#     604 self.reset_results()
#     606 with self.model:
# --> 607     self.trace = pm.sample_smc(
#     608         progressbar=self.verbose,
#     609         compute_convergence_checks=False,
#     610         **kwargs,
#     611     )
#     613 # add log-likelihood to trace
#     614 if self.verbose:
#
# File ~/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/smc/sampling.py:193, in sample_smc(draws, kernel, start, model, random_seed, chains, cores, compute_convergence_checks, return_inferencedata, idata_kwargs, progressbar, compile_kwargs, **kernel_kwargs)
#     184 params = (
#     185     draws,
#     186     kernel,
#     187     start,
#     188     model,
#     189 )
#     191 t1 = time.time()
# --> 193 results = run_chains(chains, progressbar, params, random_seed, kernel_kwargs, cores)
#     195 (
#     196     traces,
#     197     sample_stats,
#     198     sample_settings,
#     199 ) = zip(*results)
#     201 trace = MultiTrace(traces)
#
# File ~/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/smc/sampling.py:405, in run_chains(chains, progressbar, params, random_seed, kernel_kwargs, cores)
#     398                 # update the progress bar for this task:
#     399                 progress.update(
#     400                     status=f"Stage: {stage} Beta: {beta:.3f}",
#     401                     task_id=task_id,
#     402                     refresh=True,
#     403                 )
# --> 405 return tuple(cloudpickle.loads(r.result()) for r in done)
#
# File ~/miniconda3/envs/bayes_spec-dev/lib/python3.13/site-packages/pymc/smc/sampling.py:405, in <genexpr>(.0)
#     398                 # update the progress bar for this task:
#     399                 progress.update(
#     400                     status=f"Stage: {stage} Beta: {beta:.3f}",
#     401                     task_id=task_id,
#     402                     refresh=True,
#     403                 )
# --> 405 return tuple(cloudpickle.loads(r.result()) for r in done)
#
# File ~/miniconda3/envs/bayes_spec-dev/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniconda3/envs/bayes_spec-dev/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# RecursionError: maximum recursion depth exceeded

# %%
start = time.time()
model.sample(
    #init = "advi+adapt_diag", # initialization strategy
    init="auto",
    tune = 1000, # tuning samples
    draws = 1000, # posterior samples
    chains = 8, # number of independent chains
    cores = 8, # number of parallel chains
    init_kwargs = {"rel_tolerance": 0.05, "abs_tolerance": 0.05, "learning_rate": 0.01}, # VI initialization arguments
    nuts_kwargs = {"target_accept": 0.8}, # NUTS arguments
)
end = time.time()
print(f"Runtime: {(end-start)/60.0:.2f} minutes")

# %%
model.solve(kl_div_threshold=0.1)

# %%
print("solutions:", model.solutions)
pm.summary(model.trace.solution_0)

# %% [markdown]
# We generate posterior predictive checks as well as a trace plot of the individual chains. In the posterior predictive plot, we show each chain as a different color. Each line is one posterior sample.

# %%
posterior = model.sample_posterior_predictive(
    thin=100, # keep one in {thin} posterior samples
)
_ = plot_predictive(model.data, posterior.posterior_predictive)

# %%
from bayes_spec.plots import plot_traces

_ = plot_traces(model.trace.posterior, model.cloud_freeRVs)

# %% [markdown]
# We can inspect the posterior distribution pair plots. First, the normalized, free cloud parameters.

# %%
from bayes_spec.plots import plot_pair

_ = plot_pair(
    model.trace.posterior, # samples
    model.cloud_freeRVs, # var_names to plot
    labeller=model.labeller, # label manager
)

# %% [markdown]
# Notice that there are three posterior modes. These correspond to the three clouds of the model. We can plot the posterior distributions of the deterministic quantities for a single cloud.

# %%
_ = plot_pair(
    model.trace.solution_0.sel(cloud=0), # samples
    model.cloud_deterministics, # var_names to plot
    labeller=model.labeller, # label manager
)

# %%
_ = plot_pair(
    model.trace.solution_0.sel(cloud=1), # samples
    model.cloud_deterministics, # var_names to plot
    labeller=model.labeller, # label manager
)

# %%
_ = plot_pair(
    model.trace.solution_0.sel(cloud=2), # samples
    model.cloud_deterministics, # var_names to plot
    labeller=model.labeller, # label manager
)

# %% [markdown]
# Finally, we can get the posterior statistics, Bayesian Information Criterion (BIC), etc.

# %%
point_stats = az.summary(model.trace.solution_0, var_names=model.cloud_deterministics, kind='stats', hdi_prob=0.68)
print("BIC:", model.bic())
display(point_stats)
